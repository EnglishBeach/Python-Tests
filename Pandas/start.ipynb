# %%
import pandas as pd
import numpy as np

# %%
URL = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"
df = pd.read_csv(URL)
wf = pd.read_csv(f'D:\WORKS\Python-Tests\Pandas\wild_data.csv')

# %% [markdown]
# # Df

# %%
df
sepr='\n'+'*'*80+'\n'

# %%
df.describe()
# include=['object']
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %%
print(len(df['Age'].values))
df['Age'].values
# Out:
# 887
# array([22.  , 38.  , 26.  , 35.  , 35.  , 27.  , 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 23.  ,
#        31.  , 22.  , 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  , 26.  ,
#        19.  , 24.  , 23.  , 40.  , 48.  , 18.  , 66.  , 28.  , 42.  ,
#        18.  , 21.  , 18.  , 14.  , 40.  , 27.  ,  3.  , 19.  , 30.  ,
#        20.  , 27.  , 16.  , 18.  ,  7.  , 21.  , 49.  , 29.  , 65.  ,
#        46.  , 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,  4.  ,
#        64.  ,  7.  , 29.  , 19.  , 17.  , 26.  , 32.  , 16.  , 21.  ,
#        26.  , 32.  , 25.  , 23.  , 28.  ,  0.83, 30.  , 22.  , 29.  ,
#        31.  , 28.  , 17.  , 33.  , 16.  , 20.  , 23.  , 24.  , 29.  ,
#        20.  , 46.  , 26.  , 59.  , 22.  , 71.  , 23.  , 34.  , 34.  ,
#        28.  , 29.  , 21.  , 33.  , 37.  , 28.  , 21.  , 29.  , 38.  ,
#        28.  , 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 , 29.  ,
# ...

# %%
print(
df['Age'].count(),
df['Pclass'].value_counts(),
sep=sepr,
)
# Out:
# 887
# ********************************************************************************
# 3    487
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Age'].value_counts(normalize=True)
# Out:
# 22.00    0.043968
# 28.00    0.041714
# 18.00    0.040586
# 21.00    0.038331
# 24.00    0.038331
#            ...
# 0.92     0.001127
# 23.50    0.001127
# 36.50    0.001127
# 55.50    0.001127
# 74.00    0.001127
# Name: Age, Length: 89, dtype: float64

# %%
df.sort_values(by=['Pclass','Age'],ascending=[True,False])
# Out:
#      Survived  Pclass                                 Name     Sex    Age  \
# 627         1       1  Mr. Algernon Henry Wilson Barkworth    male  80.00
# 95          0       1             Mr. George B Goldschmidt    male  71.00
# 490         0       1               Mr. Ramon Artagaveytia    male  71.00
# 741         0       1          Capt. Edward Gifford Crosby    male  70.00
# 53          0       1        Mr. Engelhart Cornelius Ostby    male  65.00
# ..        ...     ...                                  ...     ...    ...
# 384         0       3       Master. Sidney Leonard Goodwin    male   1.00
# 784         1       3            Master. Bertram Vere Dean    male   1.00
# 466         1       3         Miss. Helene Barbara Baclini  female   0.75
# 641         1       3                Miss. Eugenie Baclini  female   0.75
# 799         1       3       Master. Assad Alexander Thomas    male   0.42
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
mean_m = df[df['Sex'] == 'male']['Age'].mean()
mean_m = round(mean_m, 3)

mean_f = df[df['Sex'] == 'female']['Age'].mean()
mean_f = round(mean_f, 3)
print(df['Age'].mean())
print(mean_m, mean_f, sep=sepr)
# Out:
# 29.471443066516347
# 30.431
# ********************************************************************************
# 27.72

# %%
n = 2
print(
    df.loc[0:n]['Sex'],
    df.loc[0:n, 'Sex'],
    df['Sex'].loc[0:n],
     # iloc
    df.iloc[0:n + 1, 3],
     # slice
    df[0:n + 1]['Sex'],
    df['Sex'][0:n + 1],
    sep=sepr,
)
# Out:
# 0      male
# 1    female
# 2    female
# Name: Sex, dtype: object
# ********************************************************************************
# 0      male
# 1    female
# 2    female
# Name: Sex, dtype: object
# ********************************************************************************
# 0      male
# 1    female
# 2    female
# Name: Sex, dtype: object
# ********************************************************************************
# 0      male
# 1    female
# 2    female
# Name: Sex, dtype: object
# ********************************************************************************
# 0      male
# 1    female
# 2    female
# Name: Sex, dtype: object
# ********************************************************************************
# 0      male
# 1    female
# 2    female
# Name: Sex, dtype: object

# %%
df.iloc[0:4]
n = 2
print(
    # df.loc[0:n]['Sex':'Age'],
    df.loc[0:n, 'Sex':'Age'],
    df.iloc[0:n + 1, 3:5],
    df[['Sex','Age']][0:n+1],
    df.loc[[1,2], 'Sex':'Age'],
    sep=sepr,
)
# Out:
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# ********************************************************************************
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# ********************************************************************************
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# ********************************************************************************
#       Sex   Age
# 1  female  38.0
# 2  female  26.0

# %%
print(
type(df.loc[:,['Sex']]),
type(df.loc[:,'Sex']),
sep=sepr
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ********************************************************************************
# <class 'pandas.core.series.Series'>

# %%
print(
df.apply(np.max),
df[['Age','Fare']].apply(np.max),
sep=sepr
)
# Out:
# Survived                                                                   1
# Pclass                                                                     3
# Name                       the Countess. of (Lucy Noel Martha Dyer-Edward...
# Sex                                                                     male
# Age                                                                     80.0
# Siblings/Spouses Aboard                                                    8
# Parents/Children Aboard                                                    6
# Fare                                                                512.3292
# dtype: object
# ********************************************************************************
# Age      80.0000
# Fare    512.3292
# dtype: float64

# %%
print(
df['Survived'].apply(lambda x: bool(x)).head(),
df['Survived'].map({1:True,0:False}).head(),
df.replace({'Survived':{1:True,0:False}})['Survived'].head(),
sep=sepr
)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Survived, dtype: bool
# ********************************************************************************
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Survived, dtype: bool
# ********************************************************************************
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Survived, dtype: bool

# %% [markdown]
# # Wf

# %%
wf.head(1)
# Out:
#    Unnamed: 0                                             App        Category  \
# 0           0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
#
#    Rating  Reviews Size Installs  Type Price Content Rating        Genres  \
# 0     4.1      159  19M  10,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %%
wf
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10835       10836                                   Sya9a Maroc - FR
# 10836       10837                   Fr. Mike Schmitz Audio Teachings
# 10837       10838                             Parkinson Exercices FR
# 10838       10839                      The SCP Foundation DB fr nn5n
# 10839       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating  Reviews                Size     Installs  \
# ...
